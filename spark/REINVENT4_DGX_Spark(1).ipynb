# %% [markdown]
# # REINVENT4 LibInvent - NVIDIA DGX Spark
# ## DENV NS2B-NS3 Protease Inhibitor Generation
#
# **Hardware**: NVIDIA DGX Spark (128GB unified memory, GB10 GPU)
#
# **Target**: Generate ~2.5M molecules in 8-12 hours
#
# **Scaffold**: Pyrrolidine dual aromatic
#
# ---
#
# ### Quick Start
# 1. 确保所有文件已复制到正确位置
# 2. 点击 `Run All` 即可开始
# 3. 训练过程中可以在TensorBoard查看实时进度
#
# ---

# %%
# Cell 1: 环境检查和导入
import os
import sys
import shutil
import subprocess
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

print("=" * 80)
print("REINVENT4 LibInvent - DGX Spark Setup")
print("=" * 80)
print(f"\n时间: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Python版本: {sys.version}")
print(f"工作目录: {os.getcwd()}")

# 检查CUDA
try:
    import torch
    print(f"\nPyTorch版本: {torch.__version__}")
    print(f"CUDA可用: {torch.cuda.is_available()}")
    if torch.cuda.is_available():
        print(f"CUDA版本: {torch.version.cuda}")
        print(f"GPU设备: {torch.cuda.get_device_name(0)}")
        print(f"GPU内存: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
except Exception as e:
    print(f"\n⚠️ PyTorch检查失败: {e}")

print("\n✅ 环境检查完成")
# Out:
# ================================================================================
# REINVENT4 LibInvent - DGX Spark Setup
# ================================================================================
#
# 时间: 2025-11-28 13:51:14
# Python版本: 3.10.19 (main, Oct 21 2025, 16:38:01) [GCC 11.2.0]
# 工作目录: /home/august/aidd/REINVENT4
#
# PyTorch版本: 2.9.1+cu130
# CUDA可用: True
# CUDA版本: 13.0
# GPU设备: NVIDIA GB10
# GPU内存: 128.5 GB
#
# ✅ 环境检查完成
# /home/august/miniconda3/envs/reinvent4/lib/python3.10/site-packages/torch/cuda/__init__.py:283: UserWarning:
#     Found GPU0 NVIDIA GB10 which is of cuda capability 12.1.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (8.0) - (12.0)
#
#   warnings.warn(

# %%
# Cell 2: 路径配置
# 根据你的实际路径修改这些变量
REINVENT_HOME = Path.home() / "aidd" / "REINVENT4"
EXP_NAME = "spark_run12"
EXP_DIR = REINVENT_HOME / "experiments" / "runs" / EXP_NAME

print("路径配置:")
print(f"  REINVENT根目录: {REINVENT_HOME}")
print(f"  实验目录: {EXP_DIR}")

# 创建实验目录
EXP_DIR.mkdir(parents=True, exist_ok=True)
print(f"\n✅ 实验目录已创建: {EXP_DIR}")
# Out:
# 路径配置:
#   REINVENT根目录: /home/august/aidd/REINVENT4
#   实验目录: /home/august/aidd/REINVENT4/experiments/runs/spark_run12
#
# ✅ 实验目录已创建: /home/august/aidd/REINVENT4/experiments/runs/spark_run12

# %%
# Cell 3: 文件完整性检查
print("检查必需文件...\n")

required_files = {
    "Prior模型": REINVENT_HOME / "priors" / "libinvent.prior",
    "Agent模型": REINVENT_HOME / "priors" / "denv_libinvent_model_v2.model",
    "Scaffold文件": REINVENT_HOME / "data" / "pyrrolidine_dual_aryl.smi",
    "QSAR模型": REINVENT_HOME / "models" / "random_forest_champion.joblib",
    "QSAR插件": REINVENT_HOME / "reinvent_plugins" / "components" / "comp_qsar_scorer.py",
}

all_exists = True
for name, path in required_files.items():
    exists = path.exists()
    status = "✅" if exists else "❌"
    print(f"{status} {name}: {path}")
    if not exists:
        all_exists = False
        print(f"   ⚠️ 文件不存在，请手动复制！")

if all_exists:
    print("\n✅ 所有必需文件检查通过")
else:
    print("\n❌ 有文件缺失，请先复制文件再继续")
    print("\n停止执行。请复制文件后重新运行。")
    raise FileNotFoundError("缺少必需文件")
# Out:
# 检查必需文件...
#
# ✅ Prior模型: /home/august/aidd/REINVENT4/priors/libinvent.prior
# ✅ Agent模型: /home/august/aidd/REINVENT4/priors/denv_libinvent_model_v2.model
# ✅ Scaffold文件: /home/august/aidd/REINVENT4/data/pyrrolidine_dual_aryl.smi
# ✅ QSAR模型: /home/august/aidd/REINVENT4/models/random_forest_champion.joblib
# ✅ QSAR插件: /home/august/aidd/REINVENT4/reinvent_plugins/components/comp_qsar_scorer.py
#
# ✅ 所有必需文件检查通过

# %%
# Cell 4: 生成配置文件
config_content = f"""# REINVENT4 LibInvent Configuration - NVIDIA DGX Spark Optimized
# Generated at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}

run_type = "staged_learning"
device = "cuda:0"
tb_logdir = "experiments/runs/{EXP_NAME}/tensorboard"
json_out_config = "experiments/runs/{EXP_NAME}/_config.json"

[parameters]
summary_csv_prefix = "experiments/runs/{EXP_NAME}/results"
use_checkpoint = true
purge_memories = false

prior_file = "priors/libinvent.prior"
agent_file = "priors/denv_libinvent_model_v2.model"
smiles_file = "data/pyrrolidine_dual_aryl.smi"

# DGX Spark优化
batch_size = 512
unique_sequences = true
randomize_smiles = false

[learning_strategy]
type = "dap"
sigma = 128
rate = 0.00015

[diversity_filter]
type = "IdenticalMurckoScaffold"
bucket_size = 15
minscore = 0.6

[inception]
smiles_file = "data/pyrrolidine_dual_aryl.smi"
memory_size = 100
sample_size = 20

[[stage]]
max_score = 0.85
min_steps = 1000
max_steps = 5000
chkpt_file = "experiments/runs/{EXP_NAME}/checkpoint_stage1.chkpt"

[stage.scoring]
type = "arithmetic_mean"

# QSAR Activity Prediction
[[stage.scoring.component]]
[stage.scoring.component.qsar_scorer]
[[stage.scoring.component.qsar_scorer.endpoint]]
name = "DENV_Activity"
weight = 2.5
[stage.scoring.component.qsar_scorer.endpoint.params]
model_path = "models/random_forest_champion.joblib"
[stage.scoring.component.qsar_scorer.endpoint.transform]
type = "double_sigmoid"
low = 4.5
high = 9.0
coef_div = 9.0
coef_si = 8.0
coef_se = 8.0

# Stereochemistry
[[stage.scoring.component]]
[stage.scoring.component.NumAtomStereoCenters]
[[stage.scoring.component.NumAtomStereoCenters.endpoint]]
name = "Stereo_Centers"
weight = 0.6
[stage.scoring.component.NumAtomStereoCenters.endpoint.transform]
type = "reverse_sigmoid"
low = 0
high = 3
k = 1.0

# Chemical Stability Alerts
[[stage.scoring.component]]
[stage.scoring.component.CustomAlerts]
[[stage.scoring.component.CustomAlerts.endpoint]]
name = "Stability_Alerts"
weight = 1.2
[stage.scoring.component.CustomAlerts.endpoint.params]
smarts = [
    "[*;r8]", "[*;r9]", "[*;r10]",
    "[#8][#8]",
    "[#6;+]",
    "C#C",
    "[NX3][NX3]",
    "[SH]",
    "[N+](=O)[O-]",
    "S(=O)(=O)Cl",
    "[F,Cl,Br,I][C,c][F,Cl,Br,I]",
    "c1ccc2c(c1)C(=O)c1c(C2=O)cccc1",
    "C1=CC(=O)C=CC1=O",
    "[C;R1]1[C;R1][C;R1][N;R1][C;R1]1([!#1])([!#1])([!#1])",
    "[C;R1]1[C;R1]([!#1])([!#1])[C;R1]([!#1])([!#1])[N;R1][C;R1]1",
]

# Drug-likeness
[[stage.scoring.component]]
[stage.scoring.component.Qed]
[[stage.scoring.component.Qed.endpoint]]
name = "QED"
weight = 0.3

[[stage.scoring.component]]
[stage.scoring.component.SAScore]
[[stage.scoring.component.SAScore.endpoint]]
name = "SA"
weight = 0.4
[stage.scoring.component.SAScore.endpoint.transform]
type = "reverse_sigmoid"
low = 1.0
high = 5.5
k = 0.8

# Molecular Properties
[[stage.scoring.component]]
[stage.scoring.component.MolecularWeight]
[[stage.scoring.component.MolecularWeight.endpoint]]
name = "MW"
weight = 0.5
[stage.scoring.component.MolecularWeight.endpoint.transform]
type = "double_sigmoid"
low = 280.0
high = 600.0
coef_div = 600.0
coef_si = 15.0
coef_se = 15.0

[[stage.scoring.component]]
[stage.scoring.component.NumHeavyAtoms]
[[stage.scoring.component.NumHeavyAtoms.endpoint]]
name = "Heavy_Atoms"
weight = 0.4
[stage.scoring.component.NumHeavyAtoms.endpoint.transform]
type = "double_sigmoid"
low = 18
high = 45
coef_div = 45.0
coef_si = 5.0
coef_se = 5.0

[[stage.scoring.component]]
[stage.scoring.component.SlogP]
[[stage.scoring.component.SlogP.endpoint]]
name = "LogP"
weight = 0.3
[stage.scoring.component.SlogP.endpoint.transform]
type = "double_sigmoid"
low = 0.5
high = 5.0
coef_div = 5.0
coef_si = 10.0
coef_se = 10.0

[[stage.scoring.component]]
[stage.scoring.component.TPSA]
[[stage.scoring.component.TPSA.endpoint]]
name = "TPSA"
weight = 0.2
[stage.scoring.component.TPSA.endpoint.transform]
type = "double_sigmoid"
low = 30.0
high = 120.0
coef_div = 120.0
coef_si = 20.0
coef_se = 20.0

[[stage.scoring.component]]
[stage.scoring.component.HBondAcceptors]
[[stage.scoring.component.HBondAcceptors.endpoint]]
name = "HBA"
weight = 0.3
[stage.scoring.component.HBondAcceptors.endpoint.transform]
type = "reverse_sigmoid"
low = 2
high = 8
k = 0.5

[[stage.scoring.component]]
[stage.scoring.component.HBondDonors]
[[stage.scoring.component.HBondDonors.endpoint]]
name = "HBD"
weight = 0.2
[stage.scoring.component.HBondDonors.endpoint.transform]
type = "reverse_sigmoid"
low = 0
high = 4
k = 0.5

[[stage.scoring.component]]
[stage.scoring.component.NumRotBond]
[[stage.scoring.component.NumRotBond.endpoint]]
name = "Rotatable_Bonds"
weight = 0.2
[stage.scoring.component.NumRotBond.endpoint.transform]
type = "reverse_sigmoid"
low = 0
high = 9
k = 0.5

[[stage.scoring.component]]
[stage.scoring.component.NumRings]
[[stage.scoring.component.NumRings.endpoint]]
name = "Ring_Count"
weight = 0.2
[stage.scoring.component.NumRings.endpoint.transform]
type = "reverse_sigmoid"
low = 2
high = 5
k = 0.5

[[stage.scoring.component]]
[stage.scoring.component.NumAromaticRings]
[[stage.scoring.component.NumAromaticRings.endpoint]]
name = "Aromatic_Rings"
weight = 0.15
[stage.scoring.component.NumAromaticRings.endpoint.transform]
type = "reverse_sigmoid"
low = 1
high = 3
k = 0.5

# toxic alerts, originated from run15
# 1. 扩展的毒性警报
[[stage.scoring.component]]
[stage.scoring.component.CustomAlerts]
[[stage.scoring.component.CustomAlerts.endpoint]]
name = "Toxicity_Alerts"
weight = 1.5  # 高权重，因为安全性重要

[stage.scoring.component.CustomAlerts.endpoint.params]
smarts = [
    # 致突变性结构
    "N=N",  # 偶氮化合物
    "[N;R0]=[N;R0][#6]",  # 重氮化合物
    "C(=O)N(N)C(=O)",  # 肼衍生物
    "[#6][N+](=O)[O-]",  # 硝基芳烃
    
    # 反应性/毒性官能团
    "C(=O)Cl",  # 酰氯
    "OS(=O)(=O)[#6]",  # 磺酸酯
    "[#6]S(=O)(=O)F",  # 磺酰氟
    "C(=O)C(=O)",  # α-二酮
    "[#6]OO[#6]",  # 过氧化物
    
    # 潜在心脏毒性
    "[#6]c1ccc(F)cc1",  # 对氟苯基（hERG风险）
    "CN1CCN(CC1)c2",  # 哌嗪片段（某些情况）
    
    # 肝毒性相关
    "c1ccccc1[N+](=O)[O-]",  # 硝基苯
    "Nc1ccc(cc1)S(=O)(=O)N",  # 磺胺类
    
    # 基因毒性
    "[#6]=[#6]-[#6]=[O,S]",  # Michael受体
    "C=CC(=O)[#6,#7,#8]",  # α,β-不饱和羰基
    "[#7]-[#7]=C",  # 腙类
    
    # 其他高风险结构
    "[Cl,Br,I][#6][Cl,Br,I]",  # 二卤代烷
    "c1cc2OCOc2cc1",  # 亚甲二氧基（某些情况）
    "[P,S][F,Cl,Br,I]",  # 含卤素的磷/硫化合物
]

# 2. PAINS (Pan-Assay INterference compoundS) 过滤
[[stage.scoring.component]]
[stage.scoring.component.CustomAlerts]
[[stage.scoring.component.CustomAlerts.endpoint]]
name = "PAINS_Filter"
weight = 0.8

[stage.scoring.component.CustomAlerts.endpoint.params]
smarts = [
    # 常见PAINS结构
    "[#6]=[#6](C(=O)O[#6])C(=O)N",  # 烯胺类
    "O=C1C=CC(=O)C=C1",  # 醌类
    "[#6]=N-N=[#6]",  # 偶氮化合物
    "c1ccc(cc1)S(=O)(=O)O",  # 芳基磺酸
    "[OH]c1ccccc1[OH]",  # 邻苯二酚
    "N=C1C=CC(=N)C=C1",  # 醌亚胺
]

# 3. 代谢稳定性（避免快速代谢的结构）
[[stage.scoring.component]]
[stage.scoring.component.CustomAlerts]
[[stage.scoring.component.CustomAlerts.endpoint]]
name = "Metabolic_Stability"
weight = 0.6

[stage.scoring.component.CustomAlerts.endpoint.params]
smarts = [
    # 易代谢位点
    "[#6]O[#6](C)C",  # 叔丁基醚（易脱烷基）
    "c1ccccc1OC",  # 苯甲醚（易O-去甲基化）
    "[#7]C(C)(C)C",  # 叔丁胺（易N-去烷基化）
    "c1ccccc1[CH3]",  # 甲苯（易氧化）
    "[#6][CH2][OH]",  # 伯醇（易氧化）
]
"""

config_path = EXP_DIR / "config.toml"
with open(config_path, 'w') as f:
    f.write(config_content)

print(f"✅ 配置文件已生成: {config_path}")
print(f"\n配置摘要:")
print(f"  - Batch size: 512")
print(f"  - Max steps: 5000")
print(f"  - 预期分子数: ~2,560,000")
print(f"  - Learning rate: 0.00015")
print(f"  - Sigma: 128")
# Out:
# ✅ 配置文件已生成: /home/august/aidd/REINVENT4/experiments/runs/spark_run12/config.toml
#
# 配置摘要:
#   - Batch size: 512
#   - Max steps: 5000
#   - 预期分子数: ~2,560,000
#   - Learning rate: 0.00015
#   - Sigma: 128

# %%
# Cell 5: 启动REINVENT4训练
print("=" * 80)
print("启动REINVENT4训练")
print("=" * 80)
print(f"\n开始时间: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"\n预计运行时间: 8-12 小时")
print(f"预计生成分子: ~2,560,000 个\n")

# 切换到REINVENT目录
os.chdir(REINVENT_HOME)
print(f"当前目录: {os.getcwd()}\n")

# 准备命令
config_rel_path = config_path.relative_to(REINVENT_HOME)
log_path = EXP_DIR / "training.log"

cmd = f"reinvent {config_rel_path}"
print(f"执行命令: {cmd}")
print(f"日志文件: {log_path}\n")
print("=" * 80)
print("训练开始...")
print("=" * 80)
print()

# 执行训练（实时输出）
with open(log_path, 'w') as log_file:
    process = subprocess.Popen(
        cmd,
        shell=True,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        universal_newlines=True,
        bufsize=1
    )
    
    for line in process.stdout:
        print(line, end='')
        log_file.write(line)
        log_file.flush()
    
    process.wait()
    
    if process.returncode == 0:
        print("\n" + "=" * 80)
        print("✅ 训练成功完成！")
        print("=" * 80)
    else:
        print("\n" + "=" * 80)
        print(f"❌ 训练失败 (返回码: {process.returncode})")
        print("=" * 80)

print(f"\n结束时间: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ================================================================================
# 启动REINVENT4训练
# ================================================================================
#
# 开始时间: 2025-11-28 13:51:14
#
# 预计运行时间: 8-12 小时
# 预计生成分子: ~2,560,000 个
#
# 当前目录: /home/august/aidd/REINVENT4
#
# 执行命令: reinvent experiments/runs/spark_run12/config.toml
# 日志文件: /home/august/aidd/REINVENT4/experiments/runs/spark_run12/training.log
#
# ================================================================================
# 训练开始...
# ================================================================================
#
# 13:51:16 <INFO> Started REINVENT 4.7.15 (C) AstraZeneca 2017, 2023 on 2025-11-28
# 13:51:16 <INFO> Command line: /home/august/miniconda3/envs/reinvent4/bin/reinvent experiments/runs/spark_run12/config.toml
# 13:51:16 <INFO> Reading run configuration from /home/august/aidd/REINVENT4/experiments/runs/spark_run12/config.toml using format toml
# 13:51:16 <INFO> User august on host spark-a92c
# 13:51:16 <INFO> Python version 3.10.19
# 13:51:16 <INFO> PyTorch version 2.9.1+cu130, git 5811a8d7da873dd699ff6687092c225caffcf1bb
# 13:51:16 <INFO> PyTorch compiled with CUDA version 13.0
# 13:51:16 <INFO> RDKit version 2025.09.1
# 13:51:16 <INFO> Platform Linux-6.14.0-1013-nvidia-aarch64-with-glibc2.39
# 13:51:16 <INFO> CUDA driver version 580.95.05
# 13:51:16 <INFO> Number of PyTorch CUDA devices 1
# 13:51:16 <WARN> 'use_cuda' is deprecated, use 'device' instead
# 13:51:16 <INFO> Using GPU device:0 NVIDIA GB10
# 13:51:16 <INFO> GPU memory: 90211 MiB free, 122570 MiB total
# 13:51:16 <INFO> Writing TensorBoard summary to /home/august/aidd/REINVENT4/experiments/runs/spark_run12/tensorboard
# 13:51:16 <INFO> Writing JSON config file to /home/august/aidd/REINVENT4/experiments/runs/spark_run12/_config.json
# 13:51:16 <INFO> Starting 1 stage of Reinforcement Learning
# 13:51:16 <INFO> /home/august/aidd/REINVENT4/priors/libinvent.prior has valid hash:
# { 'comments': [],
#   'creation_date': 0,
#   'date_format': 'UNIX epoch',
#   'hash_id': '99944413c8f0b152c2bca0dca31aa6d3',
#   'hash_id_format': 'xxhash.xxh3_128_hex 3.4.1',
#   'model_id': '558e4fbd038c4b0ba67b03a025e657c4',
#   'model_id_format': 'uuid.uuid4 3.10.12',
#   'origina_data_source': 'ChEMBL 27',
#   'updates': []}
# 13:51:16 <INFO> Number of network parameters: 23,686,692
# 13:51:16 <INFO> Network architecture:
# Decorator(
#   (_encoder): Encoder(
#     (_embedding): Sequential(
#       (0): Embedding(38, 512)
#       (1): Dropout(p=0.2, inplace=False)
#     )
#     (_rnn): LSTM(512, 512, num_layers=3, batch_first=True, dropout=0.2, bidirectional=True)
#   )
#   (_decoder): Decoder(
#     (_embedding): Sequential(
#       (0): Embedding(36, 512)
#       (1): Dropout(p=0.2, inplace=False)
#     )
#     (_rnn): LSTM(512, 512, num_layers=3, batch_first=True, dropout=0.2)
#     (_attention): AttentionLayer(
#       (_attention_linear): Sequential(
#         (0): Linear(in_features=1024, out_features=512, bias=True)
#         (1): Tanh()
#       )
#     )
#     (_linear): Linear(in_features=512, out_features=36, bias=True)
#   )
# )
# 13:51:16 <INFO> /home/august/aidd/REINVENT4/priors/denv_libinvent_model_v2.model has valid hash:
# { 'comments': ['TL'],
#   'creation_date': 0,
#   'date_format': 'UNIX epoch',
#   'hash_id': '8c58a9592ecea86b5038ff7edda23294',
#   'hash_id_format': 'xxhash.xxh3_128_hex 3.5.0',
#   'model_id': '558e4fbd038c4b0ba67b03a025e657c4',
#   'model_id_format': 'uuid.uuid4 3.10.12',
#   'origina_data_source': 'ChEMBL 27',
#   'updates': [1760314846.2807481]}
# 13:51:16 <INFO> Number of network parameters: 23,686,692
# 13:51:16 <INFO> Network architecture:
# Decorator(
#   (_encoder): Encoder(
#     (_embedding): Sequential(
#       (0): Embedding(38, 512)
#       (1): Dropout(p=0.2, inplace=False)
#     )
#     (_rnn): LSTM(512, 512, num_layers=3, batch_first=True, dropout=0.2, bidirectional=True)
#   )
#   (_decoder): Decoder(
#     (_embedding): Sequential(
#       (0): Embedding(36, 512)
#       (1): Dropout(p=0.2, inplace=False)
#     )
#     (_rnn): LSTM(512, 512, num_layers=3, batch_first=True, dropout=0.2)
#     (_attention): AttentionLayer(
#       (_attention_linear): Sequential(
#         (0): Linear(in_features=1024, out_features=512, bias=True)
#         (1): Tanh()
#       )
#     )
#     (_linear): Linear(in_features=512, out_features=36, bias=True)
#   )
# )
# 13:51:16 <INFO> Using generator Libinvent
# 13:51:16 <INFO> Prior read from priors/libinvent.prior
# 13:51:16 <INFO> Agent read from priors/denv_libinvent_model_v2.model
# 13:51:16 <INFO> Input molecules/fragments read from file data/pyrrolidine_dual_aryl.smi
# 13:51:16 <INFO> Using reward strategy dap
# 13:51:16 <INFO> Using diversity filter IdenticalMurckoScaffold
# 13:51:16 <INFO> Diversity filter memories are retained between stages
# 13:51:16 <INFO> No SMILES for inception. Populating from first sampled batch.
# 13:51:16 <INFO> Using inception memory
# 13:51:16 <INFO> Registered scoring component ROCSSimilarity
# 13:51:16 <INFO> Registered scoring component GroupCount
# 13:51:16 <INFO> Registered scoring component FragmentQed
# 13:51:16 <INFO> Registered scoring component FragmentSlogP
# 13:51:16 <INFO> Registered scoring component FragmentMolecularWeight
# 13:51:16 <INFO> Registered scoring component FragmentTPSA
# 13:51:16 <INFO> Registered scoring component FragmentDistanceMatrix
# 13:51:16 <INFO> Registered scoring component FragmentNumAtomStereoCenters
# 13:51:16 <INFO> Registered scoring component FragmentHBondAcceptors
# 13:51:16 <INFO> Registered scoring component FragmentHBondDonors
# 13:51:16 <INFO> Registered scoring component FragmentNumRotBond
# 13:51:16 <INFO> Registered scoring component FragmentCsp3
# 13:51:16 <INFO> Registered scoring component Fragmentnumsp
# 13:51:16 <INFO> Registered scoring component Fragmentnumsp2
# 13:51:16 <INFO> Registered scoring component Fragmentnumsp3
# 13:51:16 <INFO> Registered scoring component FragmentEffectiveLength
# 13:51:16 <INFO> Registered scoring component FragmentGraphLength
# 13:51:16 <INFO> Registered scoring component FragmentLengthRatio
# 13:51:16 <INFO> Registered scoring component FragmentNumHeavyAtoms
# 13:51:16 <INFO> Registered scoring component FragmentNumHeteroAtoms
# 13:51:16 <INFO> Registered scoring component FragmentNumRings
# 13:51:16 <INFO> Registered scoring component FragmentNumAromaticRings
# 13:51:16 <INFO> Registered scoring component FragmentNumAliphaticRings
# 13:51:16 <INFO> Registered scoring component FragmentSlogP
# 13:51:16 <INFO> Registered scoring component MatchingSubstructure
# 13:51:16 <INFO> Registered scoring component MolVolume
# 13:51:16 <INFO> Registered scoring component Qed
# 13:51:16 <INFO> Registered scoring component LargestRingSize
# 13:51:16 <INFO> Registered scoring component MolecularWeight
# 13:51:16 <INFO> Registered scoring component GraphLength
# 13:51:16 <INFO> Registered scoring component NumAtomStereoCenters
# 13:51:16 <INFO> Registered scoring component HBondAcceptors
# 13:51:16 <INFO> Registered scoring component HBondDonors
# 13:51:16 <INFO> Registered scoring component NumRotBond
# 13:51:16 <INFO> Registered scoring component Csp3
# 13:51:16 <INFO> Registered scoring component numsp
# 13:51:16 <INFO> Registered scoring component numsp2
# 13:51:16 <INFO> Registered scoring component numsp3
# 13:51:16 <INFO> Registered scoring component NumHeavyAtoms
# 13:51:16 <INFO> Registered scoring component NumHeteroAtoms
# 13:51:16 <INFO> Registered scoring component NumRings
# 13:51:16 <INFO> Registered scoring component NumAromaticRings
# 13:51:16 <INFO> Registered scoring component NumAliphaticRings
# 13:51:16 <INFO> Registered scoring component SlogP
# 13:51:16 <INFO> Registered scoring component LargestRingSize
# 13:51:16 <INFO> Registered scoring component PMI
# 13:51:16 <INFO> Registered scoring component RDKitDescriptors
# 13:51:16 <INFO> Registered scoring component TanimotoSimilarity
# 13:51:16 <INFO> Registered scoring component TanimotoDistance
# 13:51:16 <INFO> Registered scoring component TPSA
# 13:51:16 <INFO> Registered scoring component SAScore
# 13:51:17 <INFO> Registered scoring component ChemProp
# 13:51:17 <INFO> Registered scoring component CustomAlerts
# 13:51:17 <INFO> Registered scoring component DockStream
# 13:51:17 <INFO> Registered scoring component ExternalProcess
# 13:51:17 <INFO> Registered scoring component REST
# 13:51:17 <INFO> Registered scoring component Icolos
# 13:51:17 <INFO> Registered scoring component MMP
# 13:51:17 <INFO> Registered scoring component Qptuna
# 13:51:17 <INFO> Registered scoring component QSARScorer
# 13:51:17 <INFO> Registered scoring component ReactionFilter
# 13:51:17 <INFO> Registered scoring component RingPrecedence
# 13:51:17 <INFO> Registered scoring component Maize
# 13:51:17 <INFO> Registered scoring component SynthSense
# 13:51:17 <INFO> Registered scoring component CAZP
# 13:51:17 <INFO> Creating scoring component qsar_scorer
# 13:51:17 <INFO> Creating scoring component NumAtomStereoCenters
# 13:51:17 <INFO> Creating filter component CustomAlerts
# 13:51:17 <INFO> Creating scoring component Qed
# 13:51:17 <INFO> Creating scoring component SAScore
# 13:51:17 <INFO> Creating scoring component MolecularWeight
# 13:51:17 <INFO> Creating scoring component NumHeavyAtoms
# 13:51:17 <INFO> Creating scoring component SlogP
# 13:51:17 <INFO> Creating scoring component TPSA
# 13:51:17 <INFO> Creating scoring component HBondAcceptors
# 13:51:17 <INFO> Creating scoring component HBondDonors
# 13:51:17 <INFO> Creating scoring component NumRotBond
# 13:51:17 <INFO> Creating scoring component NumRings
# 13:51:17 <INFO> Creating scoring component NumAromaticRings
# Skipping invalid template CN1CCN(CC1)c2
# 13:51:17 <INFO> Creating filter component CustomAlerts
# 13:51:17 <INFO> Creating filter component CustomAlerts
# 13:51:17 <INFO> Creating filter component CustomAlerts
# 13:51:17 <INFO> Writing tabular data for stage to experiments/runs/spark_run12/results_1.csv
# 13:51:17 <INFO> Starting stage 1 <<<
# 13:51:17 <INFO> Current GPU memory usage: 33285 MiB used, 89285 MiB free
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|*C|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|C(C)C*|c1ccncc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|C(C)C|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|CCC|C(*)C|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|CCC|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|CCC|C(C)C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|CCC|C*|C(C)(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|CCC|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|CCC|C*|CCSC(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|CCC|c1ccc(F)cc1*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|CCC|c1cccc(*)c1|C(C)(C)(C)C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|CCC|c1ccccc1*|c1ccccc1CSC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|c1ccc(C)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1*C|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(C)C|c1(F)ccccc1C(*)=O|C*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|*C|c1ccccc1*|CC(C)(C)C)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|C(C)C*|c1ccc(*)cc1|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|C(C)CC|C(C)C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|C(C)CC|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|C(C)C|C*|CC(C)S(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|C(C)C|CC*|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|C(C)C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|C(C)C|c1ccc(*)cc1|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|C*|c1ccccc1*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|C*|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|C*|c1ccccc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|*C|C(C)CC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|C*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|C*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|C*|c1ccccc1C)COC(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|CC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|CCC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|c1ccc(*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|c1ccccc1*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|c1ccccc1*|CC(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|c1ccccc1*|CC(C)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|c1ccccc1*|O=S(C)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|c1ccccc1*|c1ccccc1C)C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|CCC|c1ccccc1|CCC|CC(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|c1ccc(C)cc1|C*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|c1ccc(C)cc1|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|c1ccc(F)cc1|CC*|c1ccc(C)cc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|c1ccncc1C(*)=O|c1ccccc1*|CCC|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|c1ccncc1|*C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|c1ccncc1|C*|C(*)(=O)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)(F)(F)F|n1ccccc1*|c1ccc(*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(*)C|C*|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)*|CCC|C*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C(C)C|CCC*|CCC|c1ccc(*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)CC*|c1ccc(C)cc1|C*|CC(*)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)CC|C*|c1ccc(*)cc1|C(C)C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)CC|CC*|c1ccc(*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)CC|CCC|*C|c1ccccc1C)CC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)CC|CCC|CCCCC|c1ccccc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)CC|CCC|CCC|CC*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|*C|CC*|*S(=O)(C)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|*C|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C(#N)c1cccc(*)c1|c1ccccc1*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C(C)C|CCC|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C(C)C|c1ccccc1*|c1ccccc1*|O=C(C)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C(C)C|c1ccncc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C*|*C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C*|*C|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C*|C(C)C|CCC|CC(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C*|C(C)C|c1ccccc1* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C*|c1ccc(*)cc1|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C*|c1ccc(*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C*|c1ccc(F)cc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C*|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|C*|c1ccccc1*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|*C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|C(C)CC|c1ccccc1|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|C(C)C|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|C*|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|C*|CCC|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|C*|c1ccccc1* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CC(C)*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CC*|CC(*)C|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CC*|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CCC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CCC*|CCC|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CCCC|c1ccccc1*|C(=O)(C)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CCC|*C|CC(C)C)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CCC|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CCC|CC(C)C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CCC|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CCC|c1ccc(*)cc1|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CCC|c1ccccc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|CCC|c1ccccc1*|CC(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|c1ccc(C)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|c1ccc(C)cc1|c1ccc(*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|c1ccc(C)cc1|c1ccccc1*|CC(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|c1ccc(F)cc1|c1ccc(*)cc1|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|c1ccccc1*|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|c1ccccc1*|c1ccccc1*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|CCC|c1ccccc1C)c1cccc1*|CC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccc(C)cc1|C(C)CC|c1ccc(*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccc(C)cc1|C*|CC(C)C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccc(C)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccc(C)cc1|c1ccc(C)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccc(C)nc1*|c1ccccc1*|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccccc1*|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccccc1*|c1ccccc1*|C(*)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccccc1C(C)C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccccc1|CCC|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1cccnc1*|CCC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1cccnc1|CCC|c1ccccc1*|c1ccccc1* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccncc1|CC*|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccncc1|CCC*|c1cccc(*)c1|CC(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ccncc1|CCC|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1ncccc1|C*|c1ccccc1*|CCC|c1ccc(C)cc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|c1nccnc1|C*|CC(C)*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(C)C|n1ccccc1|CCC|C*|c1c(F)cccc1C(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(*)(F)F|C*|C(C)C|CCC|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(*)(F)F|CCC|c1ccccc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(*)(F)F|CCC|c1ccccc1|c1ccccc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(*)F|C(C)C|*C|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(*)F|C(C)C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(*)F|CCC|c1ccc(F)cc1|c1ccc(*)cc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(*)F|CCC|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(*)F|c1ccccc1|CCC|CCC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(*)F|c1ccncc1|c1ccc(*)cc1|CC(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|C(C)CCOc1ccccc1C(=O)*|CC(C)*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|C(C)C|C(C)(C)*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|C(C)C|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|C(C)C|C*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|C(C)C|CC*|C(*)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|C(C)C|CCOc1cccc(*)c1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|C(C)C|c1ccccc1*|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|C(C)C|c1ccccc1*|C(*)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|C(C)C|c1ccccc1|C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|C*|CCC|CCC|CS(*)(=O)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CC*|CC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CC*|CCC|CC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CC*|c1ccc(*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC*|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCCCC|CC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|C*|CC(C)(C)C)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|C*|CCCS(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|CCC*|C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|CCC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|CCC|*C|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|CCC|c1ccccc1* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|c1ccc(*)cc1|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|c1ccc(*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|c1ccc(*)cc1|c1ccc(S(=O)(*)=O)cc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|c1ccccc1*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|c1ccccc1*|CC(C)C)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|CCC|c1ccccc1*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|O(CC)CCC(=O)*|C*|c1ccc(C)cc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|c1ccccc1*|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|c1ccccc1|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|c1ccncc1*|c1ccc(*)cc1|c1ccc(C)cc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|c1ccncc1C(=O)*|C(C)C|CC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|c1ccncc1|CC*|CC(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|c1ccncc1|CCC|C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)*|n1ccccc1C#N|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)F)*|CCC|c1ccccc1*|CC(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)F|CCC|CCC*|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C(F)(F)(F)F|CCC|CCC|C*|c1ccccc1C)CC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|*C|*C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|*C|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|*C|CCC|CCC|CC(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|*C|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(*)C|CC(C)*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(=O)(C)*|C(C)*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C*|C*|CC(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)CC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)CC*|c1ccccc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)CCOc1ccccc1*|C*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)CC|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|C(C)CC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|C*|C(C)(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|C*|CC(C)C)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|C*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|C*|CCS(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|C*|c1ccccc1* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|CC(C)*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|CC*|*C(C)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|CCC*|CC(*)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|CCC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|CCC|C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|c1ccc(*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|c1ccc(*)cc1|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|c1ccc(F)cc1*|CC(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|c1ccc(OC)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|c1ccccc1*|CC(C)(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|c1ccccc1*|CC(C)C(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|c1ccccc1*|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|c1ccccc1*|O=S(C)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C(C)C|c1ccccc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C*|*C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C*|CC*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C*|CC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C*|CCC|CC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C*|CCC|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C*|c1ccc(F)cc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C*|c1cccc(*)c1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|C*|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CC(=O)*|CCC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CC(C)CC(C)C|CC*|CC(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CC*|C(C)C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CC*|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CC*|CC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CC*|c1ccc(*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CC*|c1ccccc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CC*|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC(*)=O|CCC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC(C)C|c1ccccc1*|*S(C)(=O)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC*|C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC*|C*|c1ccccc1C)CC)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC*|CCC|CC(C)(C)NC(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC*|c1ccc(*)cc1|CC(C)(C)C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC*|c1cccc(*)c1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC*|c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCCCOCC(=O)*|c1ccccc1*|CCC|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCCC|CCC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC|*C|CC(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC|*C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC|*C|c1ccccc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC|C(C)*|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC|C(C)C|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccc([*])cc1C1N([*])C(c2ccc([*])cc2)C(C(=O)N[*])C1C*|CCC|C(C)C|CCC|c1ccccc1 could not be converted
# ...
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1cc(F)c(C)cc1|C(C)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1cc(F)ccc1C(=O)*|c1ccccc1C)C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1cc(F)ccc1C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1C|c1ccccc1C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|CC(C)C)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|CC(C)CCCC(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|CS(*)(=O)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|CS(=O)(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|CS(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|c1(C)ccccc1S(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|c1ccc(C)cc1C)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|c1ccc(C)cc1S(=O)(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|c1ccc(F)cc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|c1ccc(S(=O)(*)=O)cc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|c1ccccc1C)CC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|c1ccccc1CS(=O)(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C)cc1|c1ccccc1S(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C*)cc1|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(C*)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(CC)cc1|*C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(Cl)cc1|c1ccc(C)cc1S(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(Cl)cc1|c1cccc(F)c1S(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1C)CC*|c1ccccc1S(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1C*|c1ccccc1C)C(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1|C(C)(C)CCS(=O)(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1|CC(C)CCS(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1|CC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1|CCCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1|O=S(C)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1|c1ccccc1F)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1|c1ccccc1S(*)(=O)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(F)cc1|c1ccccc1S(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(OCC)cc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccc(S(=O)(*)=O)cc1|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1cccc(C)c1C*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1cccc(C)c1C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1cccc(C)c1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1cccc(C)c1|c1ccc(C)cc1S(*)(=O)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1cccc(F)c1C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1cccc(S(=O)(*)=O)c1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C(*)=O|c1ccccc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C(=O)*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C(C)C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C(C)C*|c1ccccc1C)CCC(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C(O)C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C)*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C)*|c1ccccc1C)CS(*)(=O)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C)C*|c1cccc(C)c1S(*)(=O)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C)CC*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C)c1cccc(C)c1*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1C*|c1ccccc1C)CCC(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1CC*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1CCC*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1COC(=O)*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1Oc1ccccc1C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|C(C)C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|CC(C)CC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|CCCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|c1ccc(C)cc1C(C)C)CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|c1ccc(C)cc1S(=O)(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|c1ccc(F)cc1CS(=O)(*)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|c1cccc(C)c1S(=O)(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|c1cccc(S(*)(=O)=O)c1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|c1ccccc1 could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|c1ccccc1C(=O)* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|c1ccccc1C)CC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|c1ccccc1C)CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|c1ccccc1CS(*)(=O)=O could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccccc1|c1cccnc1S(=O)(*)=O|c1ccccc1C)C* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccncc1C*|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccncc1|CCC could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccncc1|CCC* could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccoc1C*|C(C)C could not be converted
# 13:51:25 <WARN> reinvent_plugins.normalizers.rdkit_smiles: c1ccsc1C1N([*])C(c2ccccc2)C(C(=O)N[*])C1c1ccoc1|C(C)C could not be converted
# 13:51:49 <CRIT> Received exception ('[*] is not supported! Supported tokens are ['<pad>', '$', '^', '#', '(', ')', '*', '-', '1', '2', '3', '4', '5', '6', '=', 'Br', 'C', 'Cl', 'F', 'N', 'O', 'S', '[N+]', '[N-]', '[N]', '[O-]', '[O]', '[S+]', '[n+]', '[nH]', '[s+]', 'c', 'n', 'o', 's', '|'].'): saving checkpoint and then terminate
# [QSAR Scorer] ✓ Model loaded from models/random_forest_champion.joblib
# [QSAR Scorer] Processing 660 SMILES strings
# [QSAR Scorer]   CC(C)c1cccc(C2CC(C(=O)NS(C)(=O)=O)C(c3ccc(-c4cccc( -> pIC50=7.7600
# [QSAR Scorer]   CCCNC(=O)C1CC(c2cccc(-c3ccccc3)c2)N(C(=O)c2ccccc2) -> pIC50=7.7856
# [QSAR Scorer]   CCc1cccc(C2CC(C(=O)NS(=O)(=O)c3ccc(F)cc3)C(c3ccccc -> pIC50=7.6620
# [QSAR Scorer] Predictions: min=7.46, max=7.81, mean=7.65
# Traceback (most recent call last):
#   File "/home/august/miniconda3/envs/reinvent4/bin/reinvent", line 7, in <module>
#     sys.exit(main_script())
#   File "/home/august/aidd/REINVENT4/reinvent/Reinvent.py", line 196, in main_script
#     main(args)
#   File "/home/august/aidd/REINVENT4/reinvent/Reinvent.py", line 165, in main
#     runner(
#   File "/home/august/aidd/REINVENT4/reinvent/runmodes/RL/run_staged_learning.py", line 204, in run_staged_learning
#     terminate = optimize(package.terminator)
#   File "/home/august/aidd/REINVENT4/reinvent/runmodes/RL/learning.py", line 164, in optimize
#     agent_lls, prior_lls, augmented_nll, loss = self.update(results, orig)
#   File "/home/august/aidd/REINVENT4/reinvent/runmodes/RL/libinvent.py", line 22, in update
#     return self._update_common(results, orig_smilies)
#   File "/home/august/aidd/REINVENT4/reinvent/runmodes/RL/learning.py", line 252, in _update_common
#     return self.reward_nlls(
#   File "/home/august/aidd/REINVENT4/reinvent/runmodes/RL/reward.py", line 222, in __call__
#     lls = agent.likelihood_smiles(_orig_smilies)
#   File "/home/august/aidd/REINVENT4/reinvent/models/model_factory/libinvent_adapter.py", line 38, in likelihood_smiles
#     return self.likelihood_smiles_common(DecoratorDataset, sampled_sequence_list)
#   File "/home/august/aidd/REINVENT4/reinvent/models/model_factory/model_adapter.py", line 90, in likelihood_smiles_common
#     dataset = Dataset(sequence_pairs, self.get_vocabulary())
#   File "/home/august/aidd/REINVENT4/reinvent/models/libinvent/models/dataset.py", line 51, in __init__
#     en_dec = self.vocabulary.decoration_vocabulary.encode(
#   File "/home/august/aidd/REINVENT4/reinvent/models/libinvent/models/vocabulary.py", line 106, in encode
#     raise KeyError(f"{token} is not supported! Supported tokens are {self.tokens()}.")
# KeyError: "[*] is not supported! Supported tokens are ['<pad>', '$', '^', '#', '(', ')', '*', '-', '1', '2', '3', '4', '5', '6', '=', 'Br', 'C', 'Cl', 'F', 'N', 'O', 'S', '[N+]', '[N-]', '[N]', '[O-]', '[O]', '[S+]', '[n+]', '[nH]', '[s+]', 'c', 'n', 'o', 's', '|']."
#
# ================================================================================
# ❌ 训练失败 (返回码: 1)
# ================================================================================
#
# 结束时间: 2025-11-28 13:51:50

# %%
# Cell 6: 结果分析 - 加载数据
print("=" * 80)
print("结果分析")
print("=" * 80)

# 查找结果CSV文件
csv_files = list(EXP_DIR.glob("results_*.csv"))
if not csv_files:
    print("\n❌ 未找到结果CSV文件")
else:
    csv_file = csv_files[0]
    print(f"\n加载结果文件: {csv_file.name}")
    
    df = pd.read_csv(csv_file)
    print(f"\n数据维度: {df.shape}")
    print(f"总生成分子数: {len(df):,}")
    
    # 基本统计
    print("\n" + "=" * 80)
    print("基本统计")
    print("=" * 80)
    
    valid = df[df['SMILES_state'] == 1]
    invalid = df[df['SMILES_state'] == 0]
    duplicates = df[df['SMILES_state'] == 2]
    
    print(f"\nValid SMILES: {len(valid):,} ({len(valid)/len(df)*100:.2f}%)")
    print(f"Invalid SMILES: {len(invalid):,} ({len(invalid)/len(df)*100:.2f}%)")
    print(f"Batch duplicates: {len(duplicates):,} ({len(duplicates)/len(df)*100:.2f}%)")
    
    # Unique分子
    unique_smiles = df['SMILES'].nunique()
    print(f"\nUnique SMILES: {unique_smiles:,} ({unique_smiles/len(df)*100:.2f}%)")
    
    # 分数统计
    print("\n" + "=" * 80)
    print("分数统计")
    print("=" * 80)
    
    if 'total_score' in df.columns:
        print(f"\nTotal Score:")
        print(f"  Mean: {df['total_score'].mean():.4f}")
        print(f"  Std: {df['total_score'].std():.4f}")
        print(f"  Min: {df['total_score'].min():.4f}")
        print(f"  Max: {df['total_score'].max():.4f}")
    
    if 'DENV_Activity' in df.columns:
        print(f"\nDENV Activity (pIC50):")
        print(f"  Mean: {df['DENV_Activity'].mean():.4f}")
        print(f"  Std: {df['DENV_Activity'].std():.4f}")
        print(f"  Min: {df['DENV_Activity'].min():.4f}")
        print(f"  Max: {df['DENV_Activity'].max():.4f}")
# Out:
# ================================================================================
# 结果分析
# ================================================================================
#
# 加载结果文件: results_1.csv
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[7], line 14
#      11 csv_file = csv_files[0]
#      12 print(f"\n加载结果文件: {csv_file.name}")
# ---> 14 df = pd.read_csv(csv_file)
#      15 print(f"\n数据维度: {df.shape}")
#      16 print(f"总生成分子数: {len(df):,}")
#
# File ~/miniconda3/envs/reinvent4/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/reinvent4/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/envs/reinvent4/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/reinvent4/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~/miniconda3/envs/reinvent4/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File pandas/_libs/parsers.pyx:581, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
# Cell 7: 金标准候选分子提取
print("=" * 80)
print("金标准候选分子提取")
print("=" * 80)

# 定义金标准阈值
thresholds = {
    'pIC50': 7.5,        # IC50 < ~32 nM
    'QED': 0.6,
    'SA': 5.0,
    'total_score': 0.7,
}

print(f"\n金标准阈值:")
for k, v in thresholds.items():
    print(f"  {k}: {v}")

# 筛选金标准分子
gold_mask = (
    (df['SMILES_state'] == 1) &
    (df['DENV_Activity'] >= thresholds['pIC50']) &
    (df['QED'] >= thresholds['QED']) &
    (df['SA'] <= thresholds['SA']) &
    (df['total_score'] >= thresholds['total_score'])
)

gold_df = df[gold_mask].copy()
print(f"\n金标准候选数: {len(gold_df):,}")

# 去重
gold_df_unique = gold_df.drop_duplicates(subset=['SMILES'])
print(f"去重后: {len(gold_df_unique):,}")

# 保存金标准分子
if len(gold_df_unique) > 0:
    gold_output = EXP_DIR / "gold_standard_candidates.csv"
    gold_df_unique.to_csv(gold_output, index=False)
    print(f"\n✅ 金标准候选已保存: {gold_output.name}")
    
    # 显示前10个
    print("\nTop 10金标准候选 (按pIC50排序):")
    top10 = gold_df_unique.nlargest(10, 'DENV_Activity')
    print(top10[['SMILES', 'DENV_Activity', 'QED', 'SA', 'total_score']].to_string())
else:
    print("\n⚠️ 未找到符合金标准的分子")

# %%
# Cell 8: 可视化分析
print("=" * 80)
print("可视化分析")
print("=" * 80)

# 设置绘图样式
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (16, 10)

fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('REINVENT4 Generation Results - DGX Spark', fontsize=16, fontweight='bold')

# 1. Total Score分布
axes[0, 0].hist(df['total_score'], bins=50, edgecolor='black', alpha=0.7)
axes[0, 0].axvline(df['total_score'].mean(), color='red', linestyle='--', label=f'Mean: {df["total_score"].mean():.3f}')
axes[0, 0].set_xlabel('Total Score')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].set_title('Total Score Distribution')
axes[0, 0].legend()

# 2. DENV Activity (pIC50)分布
axes[0, 1].hist(df['DENV_Activity'], bins=50, edgecolor='black', alpha=0.7, color='green')
axes[0, 1].axvline(7.5, color='red', linestyle='--', label='Gold threshold (7.5)')
axes[0, 1].set_xlabel('Predicted pIC50')
axes[0, 1].set_ylabel('Frequency')
axes[0, 1].set_title('DENV Activity Distribution')
axes[0, 1].legend()

# 3. QED分布
axes[0, 2].hist(df['QED'], bins=50, edgecolor='black', alpha=0.7, color='orange')
axes[0, 2].axvline(df['QED'].mean(), color='red', linestyle='--', label=f'Mean: {df["QED"].mean():.3f}')
axes[0, 2].set_xlabel('QED')
axes[0, 2].set_ylabel('Frequency')
axes[0, 2].set_title('QED Distribution')
axes[0, 2].legend()

# 4. SA Score分布
axes[1, 0].hist(df['SA'], bins=50, edgecolor='black', alpha=0.7, color='purple')
axes[1, 0].axvline(df['SA'].mean(), color='red', linestyle='--', label=f'Mean: {df["SA"].mean():.3f}')
axes[1, 0].set_xlabel('SA Score')
axes[1, 0].set_ylabel('Frequency')
axes[1, 0].set_title('Synthetic Accessibility Distribution')
axes[1, 0].legend()

# 5. pIC50 vs QED散点图
axes[1, 1].scatter(df['DENV_Activity'], df['QED'], alpha=0.3, s=1)
axes[1, 1].axhline(0.6, color='red', linestyle='--', alpha=0.5)
axes[1, 1].axvline(7.5, color='red', linestyle='--', alpha=0.5)
axes[1, 1].set_xlabel('Predicted pIC50')
axes[1, 1].set_ylabel('QED')
axes[1, 1].set_title('Activity vs Drug-likeness')

# 6. Step进度
step_stats = df.groupby('step')['total_score'].mean()
axes[1, 2].plot(step_stats.index, step_stats.values, linewidth=2)
axes[1, 2].set_xlabel('Training Step')
axes[1, 2].set_ylabel('Mean Total Score')
axes[1, 2].set_title('Training Progress')
axes[1, 2].grid(True, alpha=0.3)

plt.tight_layout()
plot_path = EXP_DIR / "analysis_plots.png"
plt.savefig(plot_path, dpi=300, bbox_inches='tight')
print(f"\n✅ 分析图表已保存: {plot_path.name}")
plt.show()

# %%
# Cell 9: 生成最终报告
print("=" * 80)
print("生成最终报告")
print("=" * 80)

report = f"""
REINVENT4 LibInvent Generation Report
========================================
Experiment: {EXP_NAME}
Hardware: NVIDIA DGX Spark (128GB, GB10 GPU)
Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}

Configuration
-------------
Batch Size: 512
Max Steps: 5000
Learning Rate: 0.00015
Sigma: 128
Diversity Filter Bucket Size: 15

Generation Statistics
--------------------
Total Molecules Generated: {len(df):,}
Valid SMILES: {len(valid):,} ({len(valid)/len(df)*100:.2f}%)
Invalid SMILES: {len(invalid):,} ({len(invalid)/len(df)*100:.2f}%)
Batch Duplicates: {len(duplicates):,} ({len(duplicates)/len(df)*100:.2f}%)
Unique Molecules: {unique_smiles:,} ({unique_smiles/len(df)*100:.2f}%)

Score Statistics
----------------
Total Score: {df['total_score'].mean():.4f} ± {df['total_score'].std():.4f}
DENV Activity (pIC50): {df['DENV_Activity'].mean():.4f} ± {df['DENV_Activity'].std():.4f}
QED: {df['QED'].mean():.4f} ± {df['QED'].std():.4f}
SA Score: {df['SA'].mean():.4f} ± {df['SA'].std():.4f}

Gold Standard Candidates
------------------------
Total Gold Candidates: {len(gold_df_unique):,}
Thresholds:
  - pIC50 ≥ 7.5 (IC50 < ~32 nM)
  - QED ≥ 0.6
  - SA ≤ 5.0
  - Total Score ≥ 0.7

Output Files
------------
1. {csv_file.name}
2. gold_standard_candidates.csv
3. analysis_plots.png
4. training.log
5. config.toml

Next Steps
----------
1. Review gold standard candidates
2. Run virtual screening with LigUnity
3. Select candidates for synthesis
4. Experimental validation

========================================
"""

report_path = EXP_DIR / "REPORT.txt"
with open(report_path, 'w') as f:
    f.write(report)

print(report)
print(f"\n✅ 报告已保存: {report_path.name}")
print("\n" + "=" * 80)
print("分析完成！")
print("=" * 80)

# %%
# Cell 10: TensorBoard启动指南
print("=" * 80)
print("TensorBoard可视化")
print("=" * 80)
print("\n要启动TensorBoard实时监控，请在终端运行：\n")
print(f"cd {REINVENT_HOME}")
print(f"tensorboard --logdir experiments/runs/{EXP_NAME}/tensorboard --bind_all\n")
print("然后在浏览器打开: http://localhost:6006\n")
print("=" * 80)
